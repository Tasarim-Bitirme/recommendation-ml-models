# %% [markdown]
# **1. Import numpy and pandas libraries**

# %%
import numpy as np
import pandas as pd

# %%
#Test the libraries
print("Numpy version: ", np.__version__)
print("Pandas version: ", pd.__version__)
# Out:
# Numpy version:  1.23.4
# Pandas version:  1.5.1

# %% [markdown]
# **2. Load datasets**

# %%
# Read the data
Books = pd.read_csv('dataset/books_clean_dataset.csv', on_bad_lines='skip', sep=';', encoding='latin-1')
Users = pd.read_csv('dataset/bx_278860_users.csv', on_bad_lines='skip', sep=';', encoding='latin-1')
Ratings = pd.read_csv('dataset/bx_1149781_book_ratings.csv', on_bad_lines='skip', sep=';', encoding='latin-1')
# Out:
# C:\Users\almud\AppData\Local\Temp\ipykernel_12260\1522618593.py:2: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   Books = pd.read_csv('dataset/bx_271380_books.csv', on_bad_lines='skip', sep=';', encoding='latin-1')

# %% [markdown]
# I have got 'Python Pandas Error tokenizing data' before adding the following code:
# **on_bad_lines='skip', sep=';', encoding='latin-1**

# %%
Books.head(2)
# Out:
#          ISBN           Book-Title           Book-Author Year-Of-Publication  \
# 0  0195153448  Classical Mythology    Mark P. O. Morford                2002
# 1  0002005018         Clara Callan  Richard Bruce Wright                2001
#
#                  Publisher                                        Image-URL-S  \
# 0  Oxford University Press  http://images.amazon.com/images/P/0195153448.0...
# 1    HarperFlamingo Canada  http://images.amazon.com/images/P/0002005018.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
#
#                                          Image-URL-L
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...

# %%
Users.head(2)
# Out:
#    User-ID                   Location   Age
# 0        1         nyc, new york, usa   NaN
# 1        2  stockton, california, usa  18.0

# %%
Ratings.head(2)
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5

# %%
Books.shape
# Out:
# (271360, 8)

# %%
Ratings.shape
# Out:
# (1149780, 3)

# %%
Users.shape
# Out:
# (278858, 3)

# %% [markdown]
# ## Find out the missing variables

# %%
Books.isnull().sum()
# Out:
# ISBN                   0
# Book-Title             0
# Book-Author            1
# Year-Of-Publication    0
# Publisher              2
# Image-URL-S            0
# Image-URL-M            0
# Image-URL-L            3
# dtype: int64

# %%
Ratings.isnull().sum()
# Out:
# User-ID        0
# ISBN           0
# Book-Rating    0
# dtype: int64

# %%
Users.isnull().sum()
# Out:
# User-ID          0
# Location         0
# Age         110762
# dtype: int64

# %% [markdown]
# ## Find out the duplication(s)

# %%
Books.duplicated().sum()
# Out:
# 0

# %%
Ratings.duplicated().sum()
# Out:
# 0

# %%
Users.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Popularity-Based Filtering Recommendation System:

# %% [markdown]
# **Here we will display the top N highest rated books ( N = number of books)**

# %%
Ratings
# Out:
#          User-ID         ISBN  Book-Rating
# 0         276725   034545104X            0
# 1         276726   0155061224            5
# 2         276727   0446520802            0
# 3         276729   052165615X            3
# 4         276729   0521795028            6
# ...          ...          ...          ...
# 1149775   276704   1563526298            9
# 1149776   276706   0679447156            0
# 1149777   276709   0515107662           10
# 1149778   276721   0590442449           10
# 1149779   276723  05162443314            8
#
# [1149780 rows x 3 columns]

# %%
Books
# Out:
#               ISBN                                         Book-Title  \
# 0       0195153448                                Classical Mythology
# 1       0002005018                                       Clara Callan
# 2       0060973129                               Decision in Normandy
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4       0393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271355  0440400988                         There's a Bat in Bunk Five
# 271356  0525447644                            From One to One Hundred
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271358  0192126040                        Republic (World's Classics)
# 271359  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                  Book-Author Year-Of-Publication  \
# 0         Mark P. O. Morford                2002
# ...

# %%
name_ratings = pd.merge(Books, Ratings, on='ISBN')
number_ratings_df = name_ratings.groupby('Book-Title').count()['Book-Rating'].reset_index()
number_ratings_df.rename(columns={'Book-Rating': 'Number-of-Ratings'}, inplace=True)

# %%
number_ratings_df
# Out:
#                                                Book-Title  Number-of-Ratings
# 0        A Light in the Storm: The Civil War Diary of ...                  4
# 1                                   Always Have Popsicles                  1
# 2                    Apple Magic (The Collector's series)                  1
# 3        Ask Lily (Young Women of Faith: Lily Series, ...                  1
# 4        Beyond IBM: Leadership Marketing and Finance ...                  1
# ...                                                   ...                ...
# 241066                                  ï¿½?ï¿½?lpiraten.                  2
# 241067                 ï¿½?ï¿½?rger mit Produkt X. Roman.                  4
# 241068                            ï¿½?ï¿½?sterlich leben.                  1
# 241069                          ï¿½?ï¿½?stlich der Berge.                  3
# 241070                              ï¿½?ï¿½?thique en toc                  2
#
# [241071 rows x 2 columns]

# %%
average_rating_df = name_ratings.groupby('Book-Title').mean()['Book-Rating'].reset_index()
average_rating_df.rename(columns={'Book-Rating': 'Average-Rating'}, inplace=True)
# Out:
# C:\Users\almud\AppData\Local\Temp\ipykernel_12260\3743345720.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   average_rating_df = name_ratings.groupby('Book-Title').mean()['Book-Rating'].reset_index()

# %%
average_rating_df
# Out:
#                                                Book-Title  Average-Rating
# 0        A Light in the Storm: The Civil War Diary of ...        2.250000
# 1                                   Always Have Popsicles        0.000000
# 2                    Apple Magic (The Collector's series)        0.000000
# 3        Ask Lily (Young Women of Faith: Lily Series, ...        8.000000
# 4        Beyond IBM: Leadership Marketing and Finance ...        0.000000
# ...                                                   ...             ...
# 241066                                  ï¿½?ï¿½?lpiraten.        0.000000
# 241067                 ï¿½?ï¿½?rger mit Produkt X. Roman.        5.250000
# 241068                            ï¿½?ï¿½?sterlich leben.        7.000000
# 241069                          ï¿½?ï¿½?stlich der Berge.        2.666667
# 241070                              ï¿½?ï¿½?thique en toc        4.000000
#
# [241071 rows x 2 columns]

# %%
popularity_df = pd.merge(number_ratings_df, average_rating_df, on='Book-Title')

# %%
popularity_df
# Out:
#                                                Book-Title  Number-of-Ratings  \
# 0        A Light in the Storm: The Civil War Diary of ...                  4
# 1                                   Always Have Popsicles                  1
# 2                    Apple Magic (The Collector's series)                  1
# 3        Ask Lily (Young Women of Faith: Lily Series, ...                  1
# 4        Beyond IBM: Leadership Marketing and Finance ...                  1
# ...                                                   ...                ...
# 241066                                  ï¿½?ï¿½?lpiraten.                  2
# 241067                 ï¿½?ï¿½?rger mit Produkt X. Roman.                  4
# 241068                            ï¿½?ï¿½?sterlich leben.                  1
# 241069                          ï¿½?ï¿½?stlich der Berge.                  3
# 241070                              ï¿½?ï¿½?thique en toc                  2
#
#         Average-Rating
# ...

# %%
popularity_df.sort_values('Average-Rating', ascending=False)
# Out:
#                                                Book-Title  Number-of-Ratings  \
# 66223              Film Is: The International Free Cinema                  1
# 123125  More Secrets of Happy Children: Embrace Your P...                  1
# 96558             Jo's Boys : From the Original Publisher                  1
# 212107    The Vanished Priestess : An Annie Szabo Mystery                  1
# 72503                                    Game and Hunting                  1
# ...                                                   ...                ...
# 93628   Invaders of the Planet Earth (Choose Your Own ...                  1
# 154021    Sammy Discovers the Alphabet (Learn-With-Sammy)                  1
# 154019                    Sammy Carducci's Guide to Women                  2
# 154018  Sammle mir Kiesel am Fluï¿½?ï¿½?. Mehr als ein...                  1
# 171214                                     TRAVELLING MAN                  1
#
#         Average-Rating
# ...

# %% [markdown]
# **Take the books that have rated 250 or more**

# %%
popularity_df = popularity_df[popularity_df['Number-of-Ratings']>=250]

# %%
popularity_df
# Out:
#                                                Book-Title  Number-of-Ratings  \
# 764                                                  1984                284
# 818                                   1st to Die: A Novel                509
# 1048                                           2nd Chance                356
# 1760                                   A Bend in the Road                346
# 2281    A Child Called \It\": One Child's Courage to S...                265
# ...                                                   ...                ...
# 233850                           White Oleander : A Novel                387
# 233851       White Oleander : A Novel (Oprah's Book Club)                356
# 234740  Wicked: The Life and Times of the Wicked Witch...                326
# 234951                                        Wild Animus               2502
# 240860                                \O\" Is for Outlaw"                269
#
#         Average-Rating
# ...

# %%
popularity_df = popularity_df.sort_values('Average-Rating', ascending=False)

# %%
popularity_df
# Out:
#                                                Book-Title  Number-of-Ratings  \
# 80434   Harry Potter and the Prisoner of Azkaban (Book 3)                428
# 80422        Harry Potter and the Goblet of Fire (Book 4)                387
# 80441      Harry Potter and the Sorcerer's Stone (Book 1)                278
# 80426   Harry Potter and the Order of the Phoenix (Boo...                347
# 80414    Harry Potter and the Chamber of Secrets (Book 2)                556
# ...                                                   ...                ...
# 227701       Vinegar Hill (Oprah's Book Club (Paperback))                265
# 233635                                           Whispers                286
# 143377                                  Presumed Innocent                294
# 94382                                        Isle of Dogs                288
# 234951                                        Wild Animus               2502
#
#         Average-Rating
# ...

# %%
popularity_df
# Out:
#                                                Book-Title  Number-of-Ratings  \
# 80434   Harry Potter and the Prisoner of Azkaban (Book 3)                428
# 80422        Harry Potter and the Goblet of Fire (Book 4)                387
# 80441      Harry Potter and the Sorcerer's Stone (Book 1)                278
# 80426   Harry Potter and the Order of the Phoenix (Boo...                347
# 80414    Harry Potter and the Chamber of Secrets (Book 2)                556
# ...                                                   ...                ...
# 227701       Vinegar Hill (Oprah's Book Club (Paperback))                265
# 233635                                           Whispers                286
# 143377                                  Presumed Innocent                294
# 94382                                        Isle of Dogs                288
# 234951                                        Wild Animus               2502
#
#         Average-Rating
# ...

# %% [markdown]
# **Display the full info for the most popular books**

# %%
popularity_df = popularity_df.merge(Books, on='Book-Title').drop_duplicates('Book-Title')

# %%
popularity_df
# Out:
#                                             Book-Title  Number-of-Ratings  \
# 0    Harry Potter and the Prisoner of Azkaban (Book 3)                428
# 3         Harry Potter and the Goblet of Fire (Book 4)                387
# 5       Harry Potter and the Sorcerer's Stone (Book 1)                278
# 9    Harry Potter and the Order of the Phoenix (Boo...                347
# 13    Harry Potter and the Chamber of Secrets (Book 2)                556
# ..                                                 ...                ...
# 716       Vinegar Hill (Oprah's Book Club (Paperback))                265
# 717                                           Whispers                286
# 727                                  Presumed Innocent                294
# 733                                       Isle of Dogs                288
# 739                                        Wild Animus               2502
#
#      Average-Rating        ISBN        Book-Author Year-Of-Publication  \
# ...

# %% [markdown]
# **The variables that we are going to use in the recommendation:**

# %%
#ISBN,
# Book-Title, 
# Book-Author,
# Number-of-Ratings,
# Average-Rating,
# Image-URL-S, 
# Image-URL-M, 
# Image-URL-L

# %%
popularity_df = popularity_df[['ISBN','Book-Title', 'Book-Author', 'Number-of-Ratings', 'Average-Rating', 'Image-URL-S', 'Image-URL-M', 'Image-URL-L']]

# %%
popularity_df
# Out:
#            ISBN                                         Book-Title  \
# 0    0439136350  Harry Potter and the Prisoner of Azkaban (Book 3)
# 3    0439139597       Harry Potter and the Goblet of Fire (Book 4)
# 5    0590353403     Harry Potter and the Sorcerer's Stone (Book 1)
# 9    043935806X  Harry Potter and the Order of the Phoenix (Boo...
# 13   0439064872   Harry Potter and the Chamber of Secrets (Book 2)
# ..          ...                                                ...
# 716  0380730138       Vinegar Hill (Oprah's Book Club (Paperback))
# 717  0440216745                                           Whispers
# 727  0446359866                                  Presumed Innocent
# 733  0425182908                                       Isle of Dogs
# 739  0971880107                                        Wild Animus
#
#            Book-Author  Number-of-Ratings  Average-Rating  \
# 0        J. K. Rowling                428        5.852804
# ...

# %% [markdown]
# ### We have above the most popular 186 books based on popularity

# %%
def recommend_most_popular_books(num):
    return popularity_df.head(num)

# %%
#Let's get the first 10 highest rated books with at least 250 ratings
recommend_most_popular_books(10)
# Out:
#           ISBN                                         Book-Title  \
# 0   0439136350  Harry Potter and the Prisoner of Azkaban (Book 3)
# 3   0439139597       Harry Potter and the Goblet of Fire (Book 4)
# 5   0590353403     Harry Potter and the Sorcerer's Stone (Book 1)
# 9   043935806X  Harry Potter and the Order of the Phoenix (Boo...
# 13  0439064872   Harry Potter and the Chamber of Secrets (Book 2)
# 16  0345339681  The Hobbit : The Enchanting Prelude to The Lor...
# 17  0345339703  The Fellowship of the Ring (The Lord of the Ri...
# 26  059035342X  Harry Potter and the Sorcerer's Stone (Harry P...
# 28  0345339711     The Two Towers (The Lord of the Rings, Part 2)
# 39  0446310786                              To Kill a Mockingbird
#
#        Book-Author  Number-of-Ratings  Average-Rating  \
# 0    J. K. Rowling                428        5.852804
# 3    J. K. Rowling                387        5.824289
# 5    J. K. Rowling                278        5.737410
# ...
